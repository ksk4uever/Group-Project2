# %%
import pandas as pd

# %%
# Reference the file where the CSV is located
wine_csv_path = 'clean_winemag-data2.csv'

# Import the data into a Pandas DataFrame
wine_df = pd.read_csv(wine_csv_path)
wine_df.head()
# Out:
#     country                                        description  points  price  \
# 0  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 1        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 2        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 3        US  Much like the regular bottling from 2012, this...      87   65.0
# 4     Spain  Blackberry and raspberry aromas show a typical...      87   15.0
#
#          province                                              title  \
# 0           Douro      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1          Oregon      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2        Michigan  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3          Oregon  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4  Northern Spain  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery
# ...

# %%
wine_country_df = pd.DataFrame(wine_df["country"].value_counts())
wine_country_df.head(25)
# Out:
#               country
# US              54265
# France          17776
# Italy           16914
# Spain            6573
# Portugal         4875
# Chile            4415
# Argentina        3756
# Austria          2799
# Australia        2294
# Germany          2120
# New Zealand      1378
# South Africa     1293
# Israel            489
# Greece            461
# Canada            254
# Hungary           145
# Bulgaria          141
# Romania           120
# Uruguay           109
# Turkey             90
# Georgia            84
# Slovenia           80
# Croatia            71
# Mexico             70
# England            69

# %%
wine_country_df.to_csv("country_total.csv")

# %%
wine_df["province"].value_counts()
# Out:
# California                   36247
# Washington                    8639
# Bordeaux                      5941
# Tuscany                       5897
# Oregon                        5373
# Burgundy                      3980
# Northern Spain                3851
# Piedmont                      3729
# Mendoza Province              3264
# Veneto                        2716
# New York                      2688
# Alsace                        2440
# Northeastern Italy            2138
# Loire Valley                  1856
# Sicily & Sardinia             1797
# Champagne                     1613
# Southwest France              1503
# South Australia               1349
# Southern Italy                1349
# Provence                      1346
# Douro                         1281
# Central Italy                 1233
# Catalonia                     1164
# Rhône Valley                  1081
# Beaujolais                    1044
# Mosel                         1039
# Alentejano                     937
# ...

# %%
wine_df["country"].values
# Out:
# array(['Italy', 'Portugal', 'US', ..., 'France', 'France', 'France'],
#       dtype=object)

# %%
# Starting URL for Google Map API Call
base_url = "https://maps.googleapis.com/maps/api/geocode/json?&address="

Query_url = base_url + "country" + "&key=" + "api_key"
